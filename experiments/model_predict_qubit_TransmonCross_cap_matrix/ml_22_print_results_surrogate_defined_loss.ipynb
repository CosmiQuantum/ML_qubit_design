# %% [markdown]
# # Model Predictions (qubit_TransmonCross_cap_matrix)
# ## Capacitance --> Quantum Metal
#
# Inverse model with surrogate-defined loss

# %% [markdown]
# ## Configuration

# %%
## the parameter file has the hyperparameters
## start there if you want to change the setup

from parameters_surrogate_defined_loss import *

# %% [markdown]
# ## Library

# %%
import os, gc, math
from pathlib import Path
import numpy as np
import pandas as pd
from pandas import json_normalize
import joblib
import matplotlib.pyplot as plt

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
## load the arrays saved from ml_00

## inputs are the capacitance values (what we want to invert)
X_train = np.load(f'{DATA_DIR}/npy/x_train_one_hot_encoding_augmented.npy', allow_pickle=True)
X_val   = np.load(f'{DATA_DIR}/npy/x_val_one_hot_encoding_augmented.npy', allow_pickle=True)
X_test  = np.load(f'{DATA_DIR}/npy/x_test_one_hot_encoding_augmented.npy', allow_pickle=True)

## qiskit metal params (all continuous for transmon cross)
y_train = np.load(f'{DATA_DIR}/npy/y_train_one_hot_encoding_augmented.npy', allow_pickle=True)
y_val   = np.load(f'{DATA_DIR}/npy/y_val_one_hot_encoding_augmented.npy', allow_pickle=True)
y_test  = np.load(f'{DATA_DIR}/npy/y_test_one_hot_encoding_augmented.npy', allow_pickle=True)

## column names
with open(str(Path(METADATA_DIR) / 'X_names'), 'r') as f:
    cap_column_names = f.read().splitlines()

qiskit_param_names = np.load(str(Path(METADATA_DIR) / 'y_columns.npy'), allow_pickle=True).astype(str).tolist()

print(f'Inputs (Capacitance):     {X_train.shape[1]} columns')
print(f'Outputs (Qiskit params):  {y_train.shape[1]} columns')
print(f'\nCapacitance columns:  {cap_column_names}')
print(f'Qiskit param columns: {qiskit_param_names}')
# Out:
# Inputs (Capacitance):     6 columns
# Outputs (Qiskit params):  3 columns
#
# Capacitance columns:  ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']
# Qiskit param columns: ['design_options.connection_pads.readout.claw_length', 'design_options.connection_pads.readout.ground_spacing', 'design_options.cross_length']

# %% [markdown]
# ### Define conversion layer

# %%
## must define this class before loading the saved combined model
class ScalerConversionLayer(tf.keras.layers.Layer):
    def __init__(self, scale_a, scale_b, **kwargs):
        kwargs.setdefault('trainable', False)
        super().__init__(**kwargs)
        self._scale_a = tf.constant(scale_a, dtype=tf.float32)
        self._scale_b = tf.constant(scale_b, dtype=tf.float32)
        self._cfg = dict(
            scale_a=list(scale_a) if hasattr(scale_a, '__iter__') else scale_a,
            scale_b=list(scale_b) if hasattr(scale_b, '__iter__') else scale_b)

    def call(self, inputs):
        a = tf.cast(self._scale_a, inputs.dtype)
        b = tf.cast(self._scale_b, inputs.dtype)
        return inputs * a + b

    def get_config(self):
        config = super().get_config()
        config.update(self._cfg)
        return config

# %% [markdown]
# ### Visualize model

# %%
## decide which model file to use
encoding = 'surrogate_defined_loss'
chosen_path = f'{MODEL_DIR}/best_keras_model_{encoding}.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

## load output headers (capacitance column names the reconstruction target)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Capacitance output headers: {headers}')
# Out:
# Model path: model/best_keras_model_surrogate_defined_loss.keras
# Capacitance output headers: ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']

# %%
## look at the saved model
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    combined_model = load_model(chosen_path, compile=False,
        custom_objects={'ScalerConversionLayer': ScalerConversionLayer})
    inverse_model = combined_model.get_layer('inverse_model')
    
    ## get both the reconstructed capacitance and the predicted qiskit params
    predictions = combined_model.predict(X_test_cur, verbose=0)
    if isinstance(predictions, list):
        cap_pred = predictions[0]
        qiskit_pred = predictions[1]
    else:
        cap_pred = predictions
        qiskit_pred = inverse_model.predict(X_test_cur, verbose=0)

print(f'\n-- {os.path.basename(chosen_path)} --')
print('\nCombined model (inverse + conversion + frozen surrogate):')
combined_model.summary()
print('\nInverse model only:')
inverse_model.summary()
print(f'\nSamples: {len(X_test_cur)} | Cap targets dim: {X_test_cur.shape[1]} | Qiskit dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773100957.301125  267794 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 607 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:08:00.0, compute capability: 8.0
# —— best_keras_model_surrogate_defined_loss.keras ——
#
# Combined model (inverse + conversion + frozen surrogate):
# I0000 00:00:1773100957.627328  272670 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Model: "combined_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ combined_input (InputLayer)     │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inverse_model (Sequential)      │ (None, 3)              │           643 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaler_conversion               │ (None, 3)              │             0 │
# │ (ScalerConversionLayer)         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 6)              │         3,526 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,169 (16.29 KB)
#  Trainable params: 643 (2.51 KB)
#  Non-trainable params: 3,526 (13.77 KB)
# Inverse model only:
# Model: "inverse_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ qiskit_output (Dense)           │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 643 (2.51 KB)
#  Trainable params: 643 (2.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 291 | Cap targets dim: 6 | Qiskit dim: 3

# %%
## look at a few more model details
inv = combined_model.get_layer('inverse_model')

neurons_per_layer = [
    l.units for l in inv.layers
    if isinstance(l, Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

dropouts = [
    (l.name, float(l.rate)) for l in inv.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')
# Out:
# Best NEURONS_PER_LAYER: [64]
# Best DROPOUT rate(s): [('dropout0', 0.0)]

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50 ## change this to print more stuff

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
cap_pred   = np.asarray(cap_pred)
qiskit_pred = np.asarray(qiskit_pred)

N, P = X_test_cur.shape  ## p = number of capacitance columns

## scaled errors on capacitance reconstruction
cap_abs_errors = np.abs(X_test_cur - cap_pred)
cap_sq_errors  = (X_test_cur - cap_pred) ** 2

## building dataframe for cap reconstruction
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  X_test_cur[i, j],
            'pred': cap_pred[i, j],
            'abs_error': cap_abs_errors[i, j],
            'sq_error':  cap_sq_errors[i, j],
        })

df = pd.DataFrame(rows)

## save scaled predictions
out_csv = Path(RESULTS_DIR) / 'predictions' / f'surrogate_loss_cap_reconstruction_scaled_{encoding}.csv'
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

## pretty print persample
for i in range(N_SAMPLES_TO_SHOW):
    ## capacitance reconstruction table
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    print(f'- Sample {i} - Capacitance reconstruction (scaled)')
    print(sub.to_string(index=False))
    
    ## predicted qiskit params that produced this capacitance
    print(f'\n  Predicted Quantum Metal params (scaled):')
    for j, col_name in enumerate(qiskit_param_names):
        short_name = col_name.replace('design_options.', '')
        pred_val = qiskit_pred[i, j]
        ref_val  = y_test_cur[i, j]
        print(f'    {short_name:40s}  pred={pred_val}  ref={ref_val}  err={abs(pred_val - ref_val)}')
    print()

print('Global scaled cap reconstruction error stats:')
print('  min abs_error:', float(cap_abs_errors.min()))
print('  median abs_error:', float(np.median(cap_abs_errors)))
print('  max abs_error:', float(cap_abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/results/predictions/surrogate_loss_cap_reconstruction_scaled_surrogate_defined_loss.csv
#
# — Sample 0 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.491077 0.491418   0.000341 1.163822e-07
#   claw_to_ground 0.333713 0.334445   0.000732 5.354878e-07
#    cross_to_claw 0.324772 0.323355   0.001417 2.008686e-06
#   cross_to_cross 0.491077 0.491276   0.000199 3.964499e-08
#     claw_to_claw 0.339820 0.340507   0.000686 4.712500e-07
# ground_to_ground 0.450407 0.445164   0.005243 2.748674e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.33197689056396484  ref=0.33333333333333337  err=0.0013564427693685266
#     connection_pads.readout.ground_spacing    pred=0.17392206192016602  ref=0.15254237288135597  err=0.021379689038810046
#     cross_length                              pred=0.5184445381164551  ref=0.5151515151515151  err=0.00329302296493994
#
# — Sample 1 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.572236 0.571610   0.000626 3.915149e-07
#   claw_to_ground 0.119324 0.117430   0.001894 3.588287e-06
#    cross_to_claw 0.050609 0.061260   0.010652 1.134554e-04
#   cross_to_cross 0.572236 0.571383   0.000853 7.277851e-07
#     claw_to_claw 0.111417 0.111346   0.000071 5.004284e-09
# ground_to_ground 0.423736 0.415688   0.008049 6.477986e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.0755201205611229  ref=0.09090909090909091  err=0.015388970347968017
#     connection_pads.readout.ground_spacing    pred=0.7788792848587036  ref=0.9999999999999999  err=0.22112071514129628
#     cross_length                              pred=0.5791260004043579  ref=0.6060606060606062  err=0.02693460565624828
#
# — Sample 2 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.246398 0.249213   0.002815 7.921832e-06
#   claw_to_ground 0.110660 0.111912   0.001251 1.565963e-06
#    cross_to_claw 0.160955 0.154666   0.006289 3.955168e-05
#   cross_to_cross 0.246398 0.249318   0.002920 8.526230e-06
#     claw_to_claw 0.115185 0.116172   0.000986 9.724715e-07
# ground_to_ground 0.206347 0.201430   0.004917 2.418124e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.10690464824438095  ref=0.12121212121212124  err=0.014307472967740292
#     connection_pads.readout.ground_spacing    pred=0.04905182123184204  ref=0.0  err=0.04905182123184204
#     cross_length                              pred=0.26923322677612305  ref=0.27272727272727276  err=0.0034940459511497157
#
# — Sample 3 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.350926 0.350458   0.000469 2.196655e-07
#   claw_to_ground 0.194021 0.192579   0.001442 2.079042e-06
#    cross_to_claw 0.199637 0.201295   0.001658 2.748378e-06
#   cross_to_cross 0.350926 0.350555   0.000372 1.380562e-07
#     claw_to_claw 0.197093 0.195766   0.001327 1.761145e-06
# ground_to_ground 0.304494 0.298396   0.006098 3.718412e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.1800377070903778  ref=0.1818181818181818  err=0.0017804747278039879
#     connection_pads.readout.ground_spacing    pred=0.17346584796905518  ref=0.15254237288135597  err=0.020923475087699206
#     cross_length                              pred=0.36931514739990234  ref=0.3636363636363637  err=0.005678783763538642
#
# — Sample 4 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.209409 0.211037   0.001628  0.000003
#   claw_to_ground 0.081487 0.082560   0.001073  0.000001
#    cross_to_claw 0.108319 0.101040   0.007279  0.000053
#   cross_to_cross 0.209409 0.211003   0.001594  0.000003
#     claw_to_claw 0.082521 0.083524   0.001003  0.000001
# ground_to_ground 0.169822 0.164820   0.005002  0.000025
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.05779813975095749  ref=0.060606060606060635  err=0.0028079208551031465
#     connection_pads.readout.ground_spacing    pred=0.26496002078056335  ref=0.15254237288135597  err=0.11241764789920738
#     cross_length                              pred=0.22044610977172852  ref=0.21212121212121215  err=0.00832489765051636
#
# — Sample 5 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.476305 0.483977   0.007672  0.000059
#   claw_to_ground 0.112069 0.115012   0.002943  0.000009
#    cross_to_claw 0.117483 0.115833   0.001649  0.000003
#   cross_to_cross 0.476305 0.483838   0.007533  0.000057
#     claw_to_claw 0.111460 0.114543   0.003083  0.000010
# ground_to_ground 0.356017 0.357053   0.001036  0.000001
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.09327761083841324  ref=0.09090909090909091  err=0.002368519929322327
#     connection_pads.readout.ground_spacing    pred=0.21527481079101562  ref=0.15254237288135597  err=0.06273243790965966
#     cross_length                              pred=0.49572741985321045  ref=0.4848484848484849  err=0.010878935004725532
#
# — Sample 6 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.414738 0.415812   0.001075 1.155224e-06
#   claw_to_ground 0.249425 0.249446   0.000020 4.099548e-10
#    cross_to_claw 0.151300 0.159295   0.007995 6.391849e-05
#   cross_to_cross 0.414738 0.415799   0.001061 1.126512e-06
#     claw_to_claw 0.243995 0.244855   0.000860 7.398224e-07
# ground_to_ground 0.367197 0.362878   0.004319 1.865571e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.21363061666488647  ref=0.21212121212121213  err=0.0015094045436743475
#     connection_pads.readout.ground_spacing    pred=0.8223698139190674  ref=0.8474576271186437  err=0.025087813199576314
#     cross_length                              pred=0.4307887554168701  ref=0.42424242424242425  err=0.006546331174445863
#
# — Sample 7 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.718296 0.717475   0.000822 6.752155e-07
#   claw_to_ground 0.006933 0.014616   0.007683 5.902906e-05
#    cross_to_claw 0.048498 0.042173   0.006325 4.000854e-05
#   cross_to_cross 0.718296 0.717234   0.001062 1.128184e-06
#     claw_to_claw 0.005892 0.013060   0.007169 5.138967e-05
# ground_to_ground 0.477078 0.472332   0.004746 2.252357e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=-0.013957852497696877  ref=0.0  err=0.013957852497696877
#     connection_pads.readout.ground_spacing    pred=0.08728113770484924  ref=0.0  err=0.08728113770484924
#     cross_length                              pred=0.7302556037902832  ref=0.7575757575757578  err=0.027320153785474588
#
# — Sample 8 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.727396 0.729240   0.001845 3.402293e-06
#   claw_to_ground 0.565610 0.563898   0.001712 2.929535e-06
#    cross_to_claw 0.351159 0.372803   0.021644 4.684765e-04
#   cross_to_cross 0.727396 0.729017   0.001621 2.627877e-06
#     claw_to_claw 0.559390 0.559437   0.000047 2.214300e-09
# ground_to_ground 0.693420 0.688759   0.004661 2.172189e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.5453988909721375  ref=0.5757575757575757  err=0.03035868478543824
#     connection_pads.readout.ground_spacing    pred=0.8797813653945923  ref=0.9999999999999999  err=0.1202186346054076
#     cross_length                              pred=0.7631757855415344  ref=0.7878787878787878  err=0.02470300233725342
#
# — Sample 9 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.479908 0.478979   0.000929 8.633335e-07
#   claw_to_ground 0.196810 0.194293   0.002517 6.337424e-06
#    cross_to_claw 0.108308 0.119325   0.011016 1.213631e-04
#   cross_to_cross 0.479908 0.479025   0.000882 7.787306e-07
#     claw_to_claw 0.189715 0.189123   0.000593 3.511275e-07
# ground_to_ground 0.389957 0.383770   0.006187 3.827684e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.15677112340927124  ref=0.15151515151515152  err=0.005255971894119721
#     connection_pads.readout.ground_spacing    pred=0.7776851654052734  ref=0.8474576271186437  err=0.06977246171337026
#     cross_length                              pred=0.49101004004478455  ref=0.4848484848484849  err=0.0061615551962996284
#
# — Sample 10 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.600780 0.609815   0.009036 8.164727e-05
#   claw_to_ground 0.056548 0.055390   0.001158 1.341861e-06
#    cross_to_claw 0.068141 0.064948   0.003193 1.019401e-05
#   cross_to_cross 0.600780 0.609657   0.008878 7.881563e-05
#     claw_to_claw 0.054351 0.053536   0.000815 6.648756e-07
# ground_to_ground 0.416750 0.416668   0.000083 6.808573e-09
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.029327504336833954  ref=0.03030303030303033  err=0.0009755259661963778
#     connection_pads.readout.ground_spacing    pred=0.2074788361787796  ref=0.15254237288135597  err=0.05493646329742363
#     cross_length                              pred=0.6156824231147766  ref=0.6060606060606062  err=0.009621817054170423
#
# — Sample 11 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.493119 0.493284   0.000164 2.701958e-08
#   claw_to_ground 0.306298 0.306264   0.000034 1.141758e-09
#    cross_to_claw 0.296525 0.291718   0.004807 2.310898e-05
#   cross_to_cross 0.493119 0.493128   0.000008 6.646404e-11
#     claw_to_claw 0.311245 0.311068   0.000177 3.128293e-08
# ground_to_ground 0.441433 0.435597   0.005836 3.405807e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.30088093876838684  ref=0.3030303030303031  err=0.0021493642619162534
#     connection_pads.readout.ground_spacing    pred=0.17430143058300018  ref=0.15254237288135597  err=0.021759057701644213
#     cross_length                              pred=0.5181147456169128  ref=0.5151515151515151  err=0.0029632304653977037
#
# — Sample 12 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.537162 0.537017   0.000145 2.097531e-08
#   claw_to_ground 0.114079 0.115747   0.001669 2.784037e-06
#    cross_to_claw 0.143708 0.139514   0.004194 1.758901e-05
#   cross_to_cross 0.537162 0.537008   0.000154 2.381025e-08
#     claw_to_claw 0.115937 0.117411   0.001473 2.170890e-06
# ground_to_ground 0.399512 0.393220   0.006292 3.959503e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.10936716943979263  ref=0.12121212121212124  err=0.01184495177232861
#     connection_pads.readout.ground_spacing    pred=0.04970914125442505  ref=0.0  err=0.04970914125442505
#     cross_length                              pred=0.5647974610328674  ref=0.5757575757575757  err=0.010960114724708259
#
# — Sample 13 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.918219 0.912126   0.006093  0.000037
#   claw_to_ground 0.487888 0.481636   0.006251  0.000039
#    cross_to_claw 0.274800 0.290477   0.015677  0.000246
#   cross_to_cross 0.918219 0.912458   0.005760  0.000033
#     claw_to_claw 0.478647 0.473516   0.005132  0.000026
# ground_to_ground 0.784138 0.777205   0.006933  0.000048
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.4503754675388336  ref=0.4545454545454546  err=0.004169987006620968
#     connection_pads.readout.ground_spacing    pred=0.9253034591674805  ref=0.9999999999999999  err=0.07469654083251942
#     cross_length                              pred=0.9358267188072205  ref=0.9393939393939394  err=0.003567220586718989
#
# — Sample 14 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.139702 0.138724   0.000978 9.555817e-07
#   claw_to_ground 0.003983 0.012920   0.008936 7.985720e-05
#    cross_to_claw 0.067032 0.065422   0.001610 2.592199e-06
#   cross_to_cross 0.139702 0.138861   0.000841 7.068537e-07
#     claw_to_claw 0.005852 0.014839   0.008987 8.077224e-05
# ground_to_ground 0.095275 0.089982   0.005292 2.800898e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=-0.00792182981967926  ref=0.0  err=0.00792182981967926
#     connection_pads.readout.ground_spacing    pred=0.060419172048568726  ref=0.0  err=0.060419172048568726
#     cross_length                              pred=0.14284557104110718  ref=0.1515151515151515  err=0.008669580474044314
#
# — Sample 15 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.942930 0.938466   0.004464  0.000020
#   claw_to_ground 0.796102 0.794154   0.001948  0.000004
#    cross_to_claw 0.805132 0.807146   0.002014  0.000004
#   cross_to_cross 0.942930 0.938032   0.004899  0.000024
#     claw_to_claw 0.820620 0.817032   0.003588  0.000013
# ground_to_ground 0.917746 0.912024   0.005722  0.000033
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.8308993577957153  ref=0.8484848484848484  err=0.017585490689133065
#     connection_pads.readout.ground_spacing    pred=0.04115244746208191  ref=0.0  err=0.04115244746208191
#     cross_length                              pred=0.9820848107337952  ref=1.0000000000000002  err=0.017915189266205056
#
# — Sample 16 — Capacitance reconstruction (scaled)
#            param      ref      pred  abs_error  sq_error
#  cross_to_ground 0.000000  0.018811   0.018811  0.000354
#   claw_to_ground 0.000000 -0.005141   0.005141  0.000026
#    cross_to_claw 0.099977  0.081518   0.018460  0.000341
#   cross_to_cross 0.000000  0.018918   0.018918  0.000358
#     claw_to_claw 0.006089  0.000071   0.006019  0.000036
# ground_to_ground 0.000000  0.004032   0.004032  0.000016
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=-0.010325474664568901  ref=0.0  err=0.010325474664568901
#     connection_pads.readout.ground_spacing    pred=0.011392205953598022  ref=0.0  err=0.011392205953598022
#     cross_length                              pred=0.029423829168081284  ref=0.0  err=0.029423829168081284
#
# — Sample 17 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.142421 0.142207   0.000214 4.580294e-08
#   claw_to_ground 0.060543 0.059017   0.001526 2.328346e-06
#    cross_to_claw 0.034886 0.037457   0.002571 6.607922e-06
#   cross_to_cross 0.142421 0.142273   0.000148 2.186552e-08
#     claw_to_claw 0.055518 0.055398   0.000120 1.441421e-08
# ground_to_ground 0.118941 0.110430   0.008511 7.243274e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.015312769450247288  ref=0.03030303030303033  err=0.014990260852783044
#     connection_pads.readout.ground_spacing    pred=0.8044703006744385  ref=0.9999999999999999  err=0.1955296993255614
#     cross_length                              pred=0.14512455463409424  ref=0.1515151515151515  err=0.006390596881057253
#
# — Sample 18 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.925515 0.925318   0.000197 3.884409e-08
#   claw_to_ground 0.604348 0.606663   0.002315 5.357454e-06
#    cross_to_claw 0.598967 0.603619   0.004652 2.164174e-05
#   cross_to_cross 0.925515 0.925377   0.000138 1.900042e-08
#     claw_to_claw 0.620460 0.621564   0.001105 1.220264e-06
# ground_to_ground 0.834103 0.832592   0.001511 2.282828e-06
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.625996470451355  ref=0.6363636363636364  err=0.010367165912281373
#     connection_pads.readout.ground_spacing    pred=0.03599509596824646  ref=0.0  err=0.03599509596824646
#     cross_length                              pred=0.9579716920852661  ref=0.9696969696969697  err=0.01172527761170361
#
# — Sample 19 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.464320 0.464394   0.000074 5.429318e-09
#   claw_to_ground 0.298122 0.299070   0.000948 8.979078e-07
#    cross_to_claw 0.334910 0.330530   0.004381 1.919094e-05
#   cross_to_cross 0.464320 0.464264   0.000056 3.104471e-09
#     claw_to_claw 0.307630 0.308153   0.000522 2.729484e-07
# ground_to_ground 0.421525 0.415056   0.006469 4.184485e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.3195798993110657  ref=0.33333333333333337  err=0.013753434022267697
#     connection_pads.readout.ground_spacing    pred=0.04652756452560425  ref=0.0  err=0.04652756452560425
#     cross_length                              pred=0.5059489607810974  ref=0.5151515151515151  err=0.009202554370417726
#
# — Sample 20 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.891668 0.893434   0.001766 3.118324e-06
#   claw_to_ground 0.687523 0.691020   0.003497 1.222908e-05
#    cross_to_claw 0.691203 0.697734   0.006531 4.265029e-05
#   cross_to_cross 0.891668 0.893685   0.002017 4.068978e-06
#     claw_to_claw 0.707502 0.709751   0.002249 5.059133e-06
# ground_to_ground 0.844530 0.844460   0.000070 4.892664e-09
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.7242493033409119  ref=0.7272727272727273  err=0.0030234239318154277
#     connection_pads.readout.ground_spacing    pred=0.03830799460411072  ref=0.0  err=0.03830799460411072
#     cross_length                              pred=0.9357731342315674  ref=0.9393939393939394  err=0.003620805162372065
#
# — Sample 21 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.209401 0.209199   0.000201 4.059448e-08
#   claw_to_ground 0.160490 0.158101   0.002389 5.708923e-06
#    cross_to_claw 0.107661 0.109361   0.001701 2.892219e-06
#   cross_to_cross 0.209401 0.209207   0.000194 3.752636e-08
#     claw_to_claw 0.156565 0.154917   0.001647 2.713915e-06
# ground_to_ground 0.199076 0.192410   0.006666 4.443456e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.11978425830602646  ref=0.12121212121212124  err=0.0014278629060947845
#     connection_pads.readout.ground_spacing    pred=0.8325331807136536  ref=0.8474576271186437  err=0.014924446404990133
#     cross_length                              pred=0.21878649294376373  ref=0.21212121212121215  err=0.006665280822551578
#
# — Sample 22 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.692516 0.694285   0.001769 3.130480e-06
#   claw_to_ground 0.531483 0.532652   0.001169 1.367101e-06
#    cross_to_claw 0.498605 0.499169   0.000563 3.174069e-07
#   cross_to_cross 0.692516 0.694055   0.001539 2.367616e-06
#     claw_to_claw 0.542134 0.543051   0.000918 8.419225e-07
# ground_to_ground 0.655717 0.653785   0.001932 3.732634e-06
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.5441030263900757  ref=0.5454545454545455  err=0.0013515190644698416
#     connection_pads.readout.ground_spacing    pred=0.21378140151500702  ref=0.15254237288135597  err=0.06123902863365105
#     cross_length                              pred=0.7310861945152283  ref=0.7272727272727273  err=0.0038134672425009786
#
# — Sample 23 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.769702 0.773610   0.003909 1.527946e-05
#   claw_to_ground 0.424755 0.425220   0.000465 2.159869e-07
#    cross_to_claw 0.259371 0.270903   0.011532 1.329932e-04
#   cross_to_cross 0.769702 0.773593   0.003891 1.514370e-05
#     claw_to_claw 0.418109 0.419157   0.001048 1.098501e-06
# ground_to_ground 0.665504 0.664698   0.000806 6.498193e-07
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.397238552570343  ref=0.3939393939393939  err=0.003299158630949095
#     connection_pads.readout.ground_spacing    pred=0.8038269281387329  ref=0.8474576271186437  err=0.04363069897991079
#     cross_length                              pred=0.7934418320655823  ref=0.7878787878787878  err=0.00556304418679443
#
# — Sample 24 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.258000 0.261315   0.003315  0.000011
#   claw_to_ground 0.218740 0.220896   0.002156  0.000005
#    cross_to_claw 0.246798 0.248079   0.001281  0.000002
#   cross_to_cross 0.258000 0.261146   0.003146  0.000010
#     claw_to_claw 0.225223 0.227886   0.002664  0.000007
# ground_to_ground 0.253757 0.250550   0.003206  0.000010
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.21289905905723572  ref=0.21212121212121213  err=0.0007778469360235907
#     connection_pads.readout.ground_spacing    pred=0.176334410905838  ref=0.15254237288135597  err=0.023792038024482043
#     cross_length                              pred=0.28160345554351807  ref=0.27272727272727276  err=0.008876182816245304
#
# — Sample 25 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.873419 0.875065   0.001646 2.708505e-06
#   claw_to_ground 0.493681 0.495177   0.001496 2.238075e-06
#    cross_to_claw 0.489826 0.490310   0.000484 2.340053e-07
#   cross_to_cross 0.873419 0.875182   0.001762 3.106264e-06
#     claw_to_claw 0.505971 0.506453   0.000482 2.321472e-07
# ground_to_ground 0.759677 0.758009   0.001668 2.781758e-06
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.512660026550293  ref=0.5151515151515151  err=0.0024914886012221693
#     connection_pads.readout.ground_spacing    pred=0.05628466606140137  ref=0.0  err=0.05628466606140137
#     cross_length                              pred=0.9089747071266174  ref=0.9090909090909092  err=0.00011620196429174001
#
# — Sample 26 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.755331 0.755193   0.000138 1.913206e-08
#   claw_to_ground 0.383603 0.386647   0.003043 9.262232e-06
#    cross_to_claw 0.394723 0.386716   0.008007 6.411755e-05
#   cross_to_cross 0.755331 0.755068   0.000263 6.917511e-08
#     claw_to_claw 0.393385 0.395043   0.001658 2.747870e-06
# ground_to_ground 0.643707 0.639237   0.004470 1.998373e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.40912848711013794  ref=0.4242424242424243  err=0.01511393713228637
#     connection_pads.readout.ground_spacing    pred=0.06603476405143738  ref=0.0  err=0.06603476405143738
#     cross_length                              pred=0.8018730282783508  ref=0.8181818181818183  err=0.016308789903467513
#
# — Sample 27 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.505304 0.511559   0.006255  0.000039
#   claw_to_ground 0.523640 0.531434   0.007794  0.000061
#    cross_to_claw 0.560928 0.575275   0.014347  0.000206
#   cross_to_cross 0.505304 0.511408   0.006104  0.000037
#     claw_to_claw 0.541912 0.549530   0.007618  0.000058
# ground_to_ground 0.531207 0.533404   0.002196  0.000005
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.5527992844581604  ref=0.5454545454545455  err=0.007344739003614875
#     connection_pads.readout.ground_spacing    pred=0.17072729766368866  ref=0.15254237288135597  err=0.01818492478233269
#     cross_length                              pred=0.554425835609436  ref=0.5454545454545454  err=0.008971290154890621
#
# — Sample 28 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.545629 0.546384   0.000754 5.689215e-07
#   claw_to_ground 0.563185 0.561227   0.001958 3.834279e-06
#    cross_to_claw 0.409048 0.422999   0.013951 1.946375e-04
#   cross_to_cross 0.545629 0.546124   0.000495 2.447778e-07
#     claw_to_claw 0.563517 0.562356   0.001160 1.346621e-06
# ground_to_ground 0.570727 0.567005   0.003722 1.385478e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.544983983039856  ref=0.5454545454545455  err=0.00047056241468956816
#     connection_pads.readout.ground_spacing    pred=0.7863239049911499  ref=0.8474576271186437  err=0.061133722127493795
#     cross_length                              pred=0.5783215761184692  ref=0.5757575757575757  err=0.002564000360893548
#
# — Sample 29 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.602620 0.602964   0.000343 1.177798e-07
#   claw_to_ground 0.148766 0.147100   0.001666 2.775985e-06
#    cross_to_claw 0.066975 0.076565   0.009590 9.197357e-05
#   cross_to_cross 0.602620 0.602701   0.000081 6.511157e-09
#     claw_to_claw 0.140655 0.140507   0.000148 2.198922e-08
# ground_to_ground 0.454340 0.447462   0.006877 4.729999e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.10474248975515366  ref=0.12121212121212124  err=0.016469631456967587
#     connection_pads.readout.ground_spacing    pred=0.8287168741226196  ref=0.9999999999999999  err=0.17128312587738026
#     cross_length                              pred=0.6111882328987122  ref=0.6363636363636362  err=0.025175403464924084
#
# — Sample 30 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.567084 0.567298   0.000214 4.591029e-08
#   claw_to_ground 0.114787 0.116346   0.001559 2.430049e-06
#    cross_to_claw 0.143329 0.138734   0.004595 2.111558e-05
#   cross_to_cross 0.567084 0.567324   0.000241 5.795157e-08
#     claw_to_claw 0.116640 0.117783   0.001143 1.307121e-06
# ground_to_ground 0.418628 0.413261   0.005367 2.880713e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.11004360765218735  ref=0.12121212121212124  err=0.011168513559933896
#     connection_pads.readout.ground_spacing    pred=0.05011680722236633  ref=0.0  err=0.05011680722236633
#     cross_length                              pred=0.595039427280426  ref=0.6060606060606062  err=0.011021178780180163
#
# — Sample 31 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.657518 0.657656   0.000138 1.902350e-08
#   claw_to_ground 0.222303 0.220184   0.002120 4.492626e-06
#    cross_to_claw 0.121132 0.127661   0.006529 4.262759e-05
#   cross_to_cross 0.657518 0.657540   0.000021 4.579003e-10
#     claw_to_claw 0.214576 0.213690   0.000887 7.862758e-07
# ground_to_ground 0.515968 0.511044   0.004924 2.424901e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.18215322494506836  ref=0.1818181818181818  err=0.0003350431268865639
#     connection_pads.readout.ground_spacing    pred=0.8016442060470581  ref=0.8474576271186437  err=0.04581342107158559
#     cross_length                              pred=0.6687002778053284  ref=0.6666666666666667  err=0.0020336111386616285
#
# — Sample 32 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.611292 0.612413   0.001121  0.000001
#   claw_to_ground 0.300248 0.304841   0.004593  0.000021
#    cross_to_claw 0.320879 0.314245   0.006634  0.000044
#   cross_to_cross 0.611292 0.612412   0.001120  0.000001
#     claw_to_claw 0.308055 0.311546   0.003491  0.000012
# ground_to_ground 0.518421 0.514381   0.004040  0.000016
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.31826454401016235  ref=0.33333333333333337  err=0.015068789323171017
#     connection_pads.readout.ground_spacing    pred=0.0638398826122284  ref=0.0  err=0.0638398826122284
#     cross_length                              pred=0.6518505215644836  ref=0.6666666666666667  err=0.014816145102183098
#
# — Sample 33 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.081588 0.080764   0.000824 6.790503e-07
#   claw_to_ground 0.029170 0.030025   0.000855 7.308425e-07
#    cross_to_claw 0.102988 0.094115   0.008874 7.874430e-05
#   cross_to_cross 0.081588 0.080902   0.000686 4.703926e-07
#     claw_to_claw 0.033439 0.033904   0.000464 2.155669e-07
# ground_to_ground 0.065812 0.058207   0.007605 5.783703e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.015546382404863834  ref=0.03030303030303033  err=0.014756647898166497
#     connection_pads.readout.ground_spacing    pred=0.04878711700439453  ref=0.0  err=0.04878711700439453
#     cross_length                              pred=0.08722635358572006  ref=0.09090909090909088  err=0.0036827373233708216
#
# — Sample 34 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.654473 0.655874   0.001400 1.961225e-06
#   claw_to_ground 0.279923 0.278797   0.001126 1.268012e-06
#    cross_to_claw 0.160982 0.168400   0.007418 5.502919e-05
#   cross_to_cross 0.654473 0.655923   0.001449 2.100336e-06
#     claw_to_claw 0.272562 0.272430   0.000132 1.751850e-08
# ground_to_ground 0.535635 0.532072   0.003562 1.269132e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.2435683012008667  ref=0.2424242424242424  err=0.001144058776624296
#     connection_pads.readout.ground_spacing    pred=0.8066437244415283  ref=0.8474576271186437  err=0.04081390267711538
#     cross_length                              pred=0.6698623299598694  ref=0.6666666666666667  err=0.003195663293202644
#
# — Sample 35 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.637794 0.638961   0.001167  0.000001
#   claw_to_ground 0.354437 0.358755   0.004317  0.000019
#    cross_to_claw 0.373647 0.366490   0.007156  0.000051
#   cross_to_cross 0.637794 0.638897   0.001103  0.000001
#     claw_to_claw 0.364432 0.367153   0.002722  0.000007
# ground_to_ground 0.554764 0.552345   0.002419  0.000006
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.3784131109714508  ref=0.3939393939393939  err=0.015526282967943117
#     connection_pads.readout.ground_spacing    pred=0.0664500892162323  ref=0.0  err=0.0664500892162323
#     cross_length                              pred=0.6822865605354309  ref=0.696969696969697  err=0.014683136434266109
#
# — Sample 36 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.617479 0.619902   0.002424 5.874214e-06
#   claw_to_ground 0.456490 0.457166   0.000676 4.565851e-07
#    cross_to_claw 0.289251 0.307678   0.018426 3.395318e-04
#   cross_to_cross 0.617479 0.619786   0.002307 5.323219e-06
#     claw_to_claw 0.451520 0.453250   0.001730 2.993729e-06
# ground_to_ground 0.576924 0.576153   0.000771 5.937360e-07
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.431622177362442  ref=0.4242424242424243  err=0.007379753120017707
#     connection_pads.readout.ground_spacing    pred=0.8047908544540405  ref=0.8474576271186437  err=0.04266677266460317
#     cross_length                              pred=0.6449514031410217  ref=0.6363636363636362  err=0.008587766777385486
#
# — Sample 37 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.812777 0.814630   0.001853 3.433473e-06
#   claw_to_ground 0.195035 0.193328   0.001708 2.916028e-06
#    cross_to_claw 0.098426 0.106431   0.008005 6.408009e-05
#   cross_to_cross 0.812777 0.814278   0.001501 2.254068e-06
#     claw_to_claw 0.186507 0.186216   0.000290 8.436900e-08
# ground_to_ground 0.606719 0.603164   0.003555 1.263849e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.15439288318157196  ref=0.15151515151515152  err=0.002877731666420441
#     connection_pads.readout.ground_spacing    pred=0.779513955116272  ref=0.8474576271186437  err=0.06794367200237172
#     cross_length                              pred=0.8205527663230896  ref=0.8181818181818183  err=0.0023709481412712563
#
# — Sample 38 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.538688 0.538662   0.000026 6.984484e-10
#   claw_to_ground 0.202514 0.201490   0.001024 1.048410e-06
#    cross_to_claw 0.105008 0.117546   0.012538 1.572097e-04
#   cross_to_cross 0.538688 0.538673   0.000015 2.263125e-10
#     claw_to_claw 0.194892 0.195425   0.000532 2.834663e-07
# ground_to_ground 0.433409 0.425877   0.007532 5.673296e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.16230997443199158  ref=0.1818181818181818  err=0.01950820738619022
#     connection_pads.readout.ground_spacing    pred=0.8276965618133545  ref=0.9999999999999999  err=0.1723034381866454
#     cross_length                              pred=0.5507476925849915  ref=0.5757575757575757  err=0.025009883172584235
#
# — Sample 39 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.769215 0.767989   0.001226  0.000002
#   claw_to_ground 0.344629 0.342191   0.002438  0.000006
#    cross_to_claw 0.190387 0.202718   0.012331  0.000152
#   cross_to_cross 0.769215 0.767899   0.001316  0.000002
#     claw_to_claw 0.336031 0.334947   0.001084  0.000001
# ground_to_ground 0.637044 0.630049   0.006995  0.000049
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.31075209379196167  ref=0.33333333333333337  err=0.0225812395413717
#     connection_pads.readout.ground_spacing    pred=0.8755533695220947  ref=0.9999999999999999  err=0.12444663047790516
#     cross_length                              pred=0.7885899543762207  ref=0.8181818181818183  err=0.02959186380559764
#
# — Sample 40 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.773005 0.771792   0.001213 1.472130e-06
#   claw_to_ground 0.513940 0.514997   0.001057 1.116970e-06
#    cross_to_claw 0.524812 0.516562   0.008249 6.804991e-05
#   cross_to_cross 0.773005 0.771478   0.001527 2.332679e-06
#     claw_to_claw 0.529111 0.528223   0.000888 7.889506e-07
# ground_to_ground 0.704382 0.699144   0.005239 2.744234e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.5533661842346191  ref=0.5757575757575757  err=0.02239139152295655
#     connection_pads.readout.ground_spacing    pred=0.0693105161190033  ref=0.0  err=0.0693105161190033
#     cross_length                              pred=0.8278384208679199  ref=0.8484848484848486  err=0.020646427616928698
#
# — Sample 41 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.280103 0.286990   0.006887  0.000047
#   claw_to_ground 0.299616 0.307513   0.007897  0.000062
#    cross_to_claw 0.355082 0.379641   0.024558  0.000603
#   cross_to_cross 0.280103 0.287319   0.007216  0.000052
#     claw_to_claw 0.311971 0.320798   0.008827  0.000078
# ground_to_ground 0.298702 0.300162   0.001461  0.000002
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.31453603506088257  ref=0.3030303030303031  err=0.011505732030579474
#     connection_pads.readout.ground_spacing    pred=0.11123976111412048  ref=0.15254237288135597  err=0.041302611767235486
#     cross_length                              pred=0.3169470727443695  ref=0.30303030303030304  err=0.013916769714066468
#
# — Sample 42 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.620861 0.624026   0.003165 1.001495e-05
#   claw_to_ground 0.253265 0.252920   0.000345 1.192064e-07
#    cross_to_claw 0.235371 0.235488   0.000117 1.360670e-08
#   cross_to_cross 0.620861 0.623950   0.003089 9.543036e-06
#     claw_to_claw 0.255459 0.255154   0.000305 9.332963e-08
# ground_to_ground 0.504177 0.501272   0.002904 8.434336e-06
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.241922527551651  ref=0.2424242424242424  err=0.0005017148725914022
#     connection_pads.readout.ground_spacing    pred=0.1862335503101349  ref=0.15254237288135597  err=0.03369117742877892
#     cross_length                              pred=0.6430663466453552  ref=0.6363636363636362  err=0.006702710281718982
#
# — Sample 43 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.426586 0.424400   0.002186  0.000005
#   claw_to_ground 0.006553 0.009020   0.002467  0.000006
#    cross_to_claw 0.054492 0.047672   0.006821  0.000047
#   cross_to_cross 0.426586 0.424638   0.001948  0.000004
#     claw_to_claw 0.006058 0.008045   0.001988  0.000004
# ground_to_ground 0.285427 0.278436   0.006990  0.000049
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=-0.013104691170156002  ref=0.0  err=0.013104691170156002
#     connection_pads.readout.ground_spacing    pred=0.047194212675094604  ref=0.0  err=0.047194212675094604
#     cross_length                              pred=0.439574271440506  ref=0.45454545454545453  err=0.014971183104948549
#
# — Sample 44 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.504124 0.505449   0.001325  0.000002
#   claw_to_ground 0.167121 0.172064   0.004943  0.000024
#    cross_to_claw 0.195266 0.190649   0.004616  0.000021
#   cross_to_cross 0.504124 0.505414   0.001289  0.000002
#     claw_to_claw 0.170796 0.175340   0.004544  0.000021
# ground_to_ground 0.398401 0.393543   0.004859  0.000024
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.1686023473739624  ref=0.1818181818181818  err=0.013215834444219393
#     connection_pads.readout.ground_spacing    pred=0.06364750862121582  ref=0.0  err=0.06364750862121582
#     cross_length                              pred=0.5331062078475952  ref=0.5454545454545454  err=0.0123483376069502
#
# — Sample 45 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.321825 0.323536   0.001711 2.928483e-06
#   claw_to_ground 0.275225 0.275470   0.000245 5.985039e-08
#    cross_to_claw 0.185685 0.193513   0.007828 6.127498e-05
#   cross_to_cross 0.321825 0.323667   0.001842 3.391405e-06
#     claw_to_claw 0.271840 0.272516   0.000675 4.558949e-07
# ground_to_ground 0.316101 0.312007   0.004094 1.676133e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.24299219250679016  ref=0.2424242424242424  err=0.0005679500825477579
#     connection_pads.readout.ground_spacing    pred=0.8217793703079224  ref=0.8474576271186437  err=0.025678256810721334
#     cross_length                              pred=0.34126555919647217  ref=0.3333333333333333  err=0.007932225863138853
#
# — Sample 46 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.795008 0.788254   0.006754  0.000046
#   claw_to_ground 0.621039 0.615156   0.005883  0.000035
#    cross_to_claw 0.640845 0.633811   0.007033  0.000049
#   cross_to_cross 0.795008 0.788147   0.006861  0.000047
#     claw_to_claw 0.640695 0.633288   0.007408  0.000055
# ground_to_ground 0.758622 0.748533   0.010089  0.000102
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.6722905039787292  ref=0.6969696969696969  err=0.024679192990967658
#     connection_pads.readout.ground_spacing    pred=0.04867127537727356  ref=0.0  err=0.04867127537727356
#     cross_length                              pred=0.855804443359375  ref=0.8787878787878789  err=0.022983435428503896
#
# — Sample 47 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.712403 0.712570   0.000167 2.782438e-08
#   claw_to_ground 0.288444 0.286867   0.001578 2.489234e-06
#    cross_to_claw 0.154069 0.166647   0.012577 1.581934e-04
#   cross_to_cross 0.712403 0.712493   0.000090 8.031459e-09
#     claw_to_claw 0.280121 0.279799   0.000322 1.039926e-07
# ground_to_ground 0.578896 0.572564   0.006332 4.009128e-05
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.251598984003067  ref=0.2727272727272728  err=0.0211282887242058
#     connection_pads.readout.ground_spacing    pred=0.8694425821304321  ref=0.9999999999999999  err=0.13055741786956776
#     cross_length                              pred=0.7286422848701477  ref=0.7575757575757578  err=0.028933472705610086
#
# — Sample 48 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.393712 0.398247   0.004535 2.056984e-05
#   claw_to_ground 0.416281 0.422373   0.006091 3.710612e-05
#    cross_to_claw 0.457818 0.478435   0.020617 4.250789e-04
#   cross_to_cross 0.393712 0.398243   0.004531 2.053175e-05
#     claw_to_claw 0.431379 0.438047   0.006669 4.446999e-05
# ground_to_ground 0.416803 0.417309   0.000506 2.562007e-07
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.43580523133277893  ref=0.4242424242424243  err=0.011562807090354621
#     connection_pads.readout.ground_spacing    pred=0.15632452070713043  ref=0.15254237288135597  err=0.0037821478257744623
#     cross_length                              pred=0.4350907802581787  ref=0.42424242424242425  err=0.010848356015754457
#
# — Sample 49 — Capacitance reconstruction (scaled)
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.579936 0.581074   0.001138  0.000001
#   claw_to_ground 0.325675 0.329809   0.004134  0.000017
#    cross_to_claw 0.350458 0.343151   0.007306  0.000053
#   cross_to_cross 0.579936 0.580986   0.001050  0.000001
#     claw_to_claw 0.335253 0.337914   0.002661  0.000007
# ground_to_ground 0.506982 0.503317   0.003665  0.000013
#
#   Predicted Quantum Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.3480432629585266  ref=0.36363636363636365  err=0.015593100677837035
#     connection_pads.readout.ground_spacing    pred=0.060568541288375854  ref=0.0  err=0.060568541288375854
#     cross_length                              pred=0.6229238510131836  ref=0.6363636363636362  err=0.013439785350452649
#
# Global scaled cap reconstruction error stats:
#   min abs_error: 1.1131384831664093e-06
#   median abs_error: 0.0026062129751399377
#   max abs_error: 0.04342719455604804

# %% [markdown]
# # Unscaled

# %%
## unscale everything and look at errors in real units that we can actually understand

with open(str(Path(METADATA_DIR) / 'X_names'), 'r') as f:
    cap_names = f.read().splitlines()
qiskit_names = np.load(str(Path(METADATA_DIR) / 'y_columns.npy'), allow_pickle=True).astype(str).tolist()

## unscale input capacitance using X scalers
x_scaler_prefix = 'scaler_X'

X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'{SCALERS_DIR}/{x_scaler_prefix}_{cap_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

## unscale reconstructed capacitance using same X scalers
cap_pred_unscaled = np.asarray(cap_pred.copy())
for i in range(cap_pred_unscaled.shape[0]):
    for j in range(cap_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'{SCALERS_DIR}/{x_scaler_prefix}_{cap_name}.save')
        cap_pred_unscaled[i, j] = scaler.inverse_transform([[cap_pred_unscaled[i, j]]])[0][0]

## unscale qiskit param predictions (using ml_00 scalers)
qiskit_pred_unscaled = np.asarray(qiskit_pred.copy())
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(qiskit_pred_unscaled.shape[0]):
    for j in range(qiskit_pred_unscaled.shape[1]):
        col_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'{SCALERS_DIR}/scaler_y_{col_name}_one_hot_encoding.save')
        qiskit_pred_unscaled[i, j] = scaler.inverse_transform([[qiskit_pred_unscaled[i, j]]])[0][0]
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

n_samples, n_cap_params = X_test_unscaled.shape

## errors on cap reconstruction (unscaled)
cap_abs_errors_unscaled = np.abs(X_test_unscaled - cap_pred_unscaled)
cap_sq_errors_unscaled  = (X_test_unscaled - cap_pred_unscaled) ** 2

## build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_cap_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': X_test_unscaled[i, j],
            'pred_unscaled': cap_pred_unscaled[i, j],
            'abs_error_unscaled': cap_abs_errors_unscaled[i, j],
            'sq_error_unscaled': cap_sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

out_csv_unscaled = Path(RESULTS_DIR) / 'predictions' / f'surrogate_loss_cap_reconstruction_unscaled_{encoding}.csv'
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

## pretty print persample
for i in range(N_SAMPLES_TO_SHOW):
    ## capacitance reconstruction table
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    print(f'- Sample {i} (Unscaled) - Capacitance reconstruction')
    print(sub.to_string(index=False))
    
    ## predicted qiskit params that produced this capacitance
    print(f'\n  Predicted Quantum Metal params (unscaled):')
    for j, col_name in enumerate(qiskit_names):
        short_name = col_name.replace('design_options.', '')
        pred_val = qiskit_pred_unscaled[i, j]
        ref_val  = y_test_unscaled[i, j]
        print(f'    {short_name:40s}  pred={pred_val}  ref={ref_val}  err={abs(pred_val - ref_val)}')
    
    ## reference qiskit params
    print(f'\n  Reference Quantum Metal params (unscaled):')
    for j, col_name in enumerate(qiskit_names):
        short_name = col_name.replace('design_options.', '')
        print(f'    {short_name:40s}  ref={y_test_unscaled[i, j]}')
    print()

print('Global unscaled cap reconstruction error stats:')
print('  min abs_error:', float(cap_abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(cap_abs_errors_unscaled)))
print('  max abs_error:', float(cap_abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/results/predictions/surrogate_loss_cap_reconstruction_unscaled_surrogate_defined_loss.csv
#
# — Sample 0 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     133.51715     133.581512            0.064362           0.004143
#   claw_to_ground      96.70298      96.794426            0.091446           0.008362
#    cross_to_claw       5.98705       5.967897            0.019153           0.000367
#   cross_to_cross     133.51715     133.554718            0.037568           0.001411
#     claw_to_claw     103.12264     103.214592            0.091952           0.008455
# ground_to_ground     287.80599     286.044098            1.761892           3.104264
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00017955237126443535  ref=0.00018  err=4.4762873556466044e-07
#     connection_pads.readout.ground_spacing    pred=5.126139967615018e-06  ref=5e-06  err=1.2613996761501726e-07
#     cross_length                              pred=0.00026108670863322914  ref=0.00026  err=1.0867086332291592e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00018
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00026
#
# — Sample 1 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     148.82923     148.711182            0.118048           0.013935
#   claw_to_ground      69.91185      69.675133            0.236717           0.056035
#    cross_to_claw       2.28210       2.426041            0.143941           0.020719
#   cross_to_cross     148.82923     148.668274            0.160956           0.025907
#     claw_to_claw      72.52964      72.520164            0.009476           0.000090
# ground_to_ground     278.84301     276.138214            2.704796           7.315921
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=9.49216409935616e-05  ref=9.999999999999999e-05  err=5.0783590064383956e-06
#     connection_pads.readout.ground_spacing    pred=8.6953878053464e-06  ref=1e-05  err=1.3046121946536013e-06
#     cross_length                              pred=0.0002811115700751543  ref=0.00029  err=8.888429924845697e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=9.999999999999999e-05
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00029
#
# — Sample 2 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      87.35435      87.885368            0.531018           0.281980
#   claw_to_ground      68.82915      68.985527            0.156377           0.024454
#    cross_to_claw       3.77328       3.688293            0.084987           0.007223
#   cross_to_cross      87.35435      87.905251            0.550901           0.303491
#     claw_to_claw      73.03445      73.166534            0.132084           0.017446
# ground_to_ground     205.78769     204.135147            1.652543           2.730898
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010527853737585247  ref=0.00011  err=4.721462624147538e-06
#     connection_pads.readout.ground_spacing    pred=4.389405603433261e-06  ref=4.1e-06  err=2.89405603433261e-07
#     cross_length                              pred=0.00017884696717374027  ref=0.00018  err=1.1530328262597436e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00018
#
# — Sample 3 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     107.07535     106.986923            0.088427           0.007819
#   claw_to_ground      79.24633      79.066147            0.180183           0.032466
#    cross_to_claw       4.29602       4.318423            0.022403           0.000502
#   cross_to_cross     107.07535     107.005249            0.070101           0.004914
#     claw_to_claw      84.00537      83.827614            0.177756           0.031597
# ground_to_ground     238.77069     236.721451            2.049239           4.199381
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001294124376727268  ref=0.00013  err=5.875623272731786e-07
#     connection_pads.readout.ground_spacing    pred=5.123448318045121e-06  ref=5e-06  err=1.2344831804512028e-07
#     cross_length                              pred=0.00021187399397604167  ref=0.00021  err=1.873993976041666e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00013
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00021
#
# — Sample 4 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      80.37558      80.682762            0.307182           0.094361
#   claw_to_ground      65.18354      65.317581            0.134041           0.017967
#    cross_to_claw       3.06197       2.963604            0.098366           0.009676
#   cross_to_cross      80.37558      80.676376            0.300796           0.090478
#     claw_to_claw      68.65929      68.793678            0.134388           0.018060
# ground_to_ground     193.51323     191.832199            1.681031           2.825865
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=8.907338633434847e-05  ref=9e-05  err=9.266136656515357e-07
#     connection_pads.readout.ground_spacing    pred=5.663264346367214e-06  ref=5e-06  err=6.632643463672135e-07
#     cross_length                              pred=0.00016274722293019295  ref=0.00016  err=2.7472229301929343e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=9e-05
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00016
#
# — Sample 5 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     130.73017     132.177597            1.447427           2.095045
#   claw_to_ground      69.00516      69.372978            0.367818           0.135290
#    cross_to_claw       3.18581       3.163520            0.022290           0.000497
#   cross_to_cross     130.73017     132.151443            1.421273           2.020018
#     claw_to_claw      72.53547      72.948441            0.412971           0.170545
# ground_to_ground     256.08539     256.433533            0.348143           0.121203
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010078160994453356  ref=9.999999999999999e-05  err=7.816099445335655e-07
#     connection_pads.readout.ground_spacing    pred=5.370121471059974e-06  ref=5e-06  err=3.701214710599739e-07
#     cross_length                              pred=0.0002535900566726923  ref=0.00025  err=3.5900566726922937e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=9.999999999999999e-05
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00025
#
# — Sample 6 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     119.11446     119.317245            0.202785           0.041122
#   claw_to_ground      86.16996      86.172493            0.002533           0.000006
#    cross_to_claw       3.64280       3.750840            0.108040           0.011673
#   cross_to_cross     119.11446     119.314705            0.200245           0.040098
#     claw_to_claw      90.28754      90.402748            0.115208           0.013273
# ground_to_ground     259.84254     258.391022            1.451518           2.106905
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001404981012456119  ref=0.00014  err=4.981012456119183e-07
#     connection_pads.readout.ground_spacing    pred=8.951981726568192e-06  ref=9.1e-06  err=1.4801827343180703e-07
#     cross_length                              pred=0.00023216029512695968  ref=0.00023  err=2.1602951269596746e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00014
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00023
#
# — Sample 7 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     176.38608     176.231049            0.155031           0.024035
#   claw_to_ground      55.86690      56.827011            0.960111           0.921813
#    cross_to_claw       2.25358       2.168103            0.085477           0.007306
#   cross_to_cross     176.38608     176.185684            0.200396           0.040158
#     claw_to_claw      58.39537      59.355560            0.960190           0.921965
# ground_to_ground     296.76901     295.174103            1.594907           2.543729
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=6.539390597026795e-05  ref=7e-05  err=4.606094029732042e-06
#     connection_pads.readout.ground_spacing    pred=4.614958925230894e-06  ref=4.1e-06  err=5.149589252308945e-07
#     cross_length                              pred=0.0003309843596071005  ref=0.00034  err=9.015640392899538e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=7e-05
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00034
#
# — Sample 8 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     178.10282     178.450821            0.348001           0.121105
#   claw_to_ground     125.68193     125.468040            0.213890           0.045749
#    cross_to_claw       6.34363       6.636124            0.292494           0.085553
#   cross_to_cross     178.10282     178.408661            0.305841           0.093539
#     claw_to_claw     132.53235     132.538651            0.006301           0.000040
# ground_to_ground     369.47224     367.905975            1.566265           2.453185
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00024998164735734463  ref=0.00026  err=1.001835264265535e-05
#     connection_pads.readout.ground_spacing    pred=9.290710295317695e-06  ref=1e-05  err=7.092897046823063e-07
#     cross_length                              pred=0.0003418480046093464  ref=0.00034999999999999994  err=8.151995390653552e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00026
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00034999999999999994
#
# — Sample 9 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     131.40994     131.234634            0.175306           0.030732
#   claw_to_ground      79.59486      79.280273            0.314587           0.098965
#    cross_to_claw       3.06183       3.210703            0.148873           0.022163
#   cross_to_cross     131.40994     131.243454            0.166486           0.027718
#     claw_to_claw      83.01717      82.937798            0.079372           0.006300
# ground_to_ground     267.49113     265.411987            2.079143           4.322834
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00012173446884844452  ref=0.00011999999999999999  err=1.734468848444532e-06
#     connection_pads.readout.ground_spacing    pred=8.688342859386466e-06  ref=9.1e-06  err=4.1165714061353283e-07
#     cross_length                              pred=0.00025203332188539207  ref=0.00025  err=2.0333218853920646e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011999999999999999
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00025
#
# — Sample 10 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     154.21450     155.919281            1.704781           2.906278
#   claw_to_ground      62.06707      61.922314            0.144756           0.020954
#    cross_to_claw       2.51902       2.475873            0.043147           0.001862
#   cross_to_cross     154.21450     155.889450            1.674950           2.805458
#     claw_to_claw      64.88617      64.776955            0.109215           0.011928
# ground_to_ground     276.49530     276.467560            0.027740           0.000770
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=7.967807323439047e-05  ref=8e-05  err=3.2192676560953914e-07
#     connection_pads.readout.ground_spacing    pred=5.324125140759861e-06  ref=5e-06  err=3.241251407598607e-07
#     cross_length                              pred=0.0002931751951109618  ref=0.00029  err=3.175195110961793e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=8e-05
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00029
#
# — Sample 11 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     133.90254     133.933548            0.031008           0.000961
#   claw_to_ground      93.27707      93.272850            0.004220           0.000018
#    cross_to_claw       5.60533       5.540368            0.064962           0.004220
#   cross_to_cross     133.90254     133.904083            0.001543           0.000002
#     claw_to_claw      99.29517      99.271477            0.023693           0.000561
# ground_to_ground     284.79018     282.828979            1.961201           3.846307
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00016929070989135653  ref=0.00017  err=7.092901086434844e-07
#     connection_pads.readout.ground_spacing    pred=5.128378234076081e-06  ref=5e-06  err=1.2837823407608043e-07
#     cross_length                              pred=0.00026097786030732095  ref=0.00026  err=9.778603073209752e-07
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00017
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00026
#
# — Sample 12 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     142.21198     142.184662            0.027318           0.000746
#   claw_to_ground      69.25635      69.464859            0.208509           0.043476
#    cross_to_claw       3.54021       3.483535            0.056675           0.003212
#   cross_to_cross     142.21198     142.182861            0.029119           0.000848
#     claw_to_claw      73.13514      73.332489            0.197349           0.038947
# ground_to_ground     270.70230     268.587677            2.114623           4.471630
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010609116725390777  ref=0.00011  err=3.908832746092234e-06
#     connection_pads.readout.ground_spacing    pred=4.393284143588971e-06  ref=4.1e-06  err=2.9328414358897164e-07
#     cross_length                              pred=0.00027638315805234015  ref=0.00028  err=3.6168419476598256e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00028
#
# — Sample 13 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     214.10489     212.955353            1.149537           1.321436
#   claw_to_ground     115.96938     115.188179            0.781201           0.610275
#    cross_to_claw       5.31174       5.523588            0.211848           0.044879
#   cross_to_cross     214.10489     213.018158            1.086732           1.180987
#     claw_to_claw     121.71747     121.030128            0.687342           0.472438
# ground_to_ground     399.95898     397.629028            2.329952           5.428675
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00021862389985471964  ref=0.00022  err=1.376100145280369e-06
#     connection_pads.readout.ground_spacing    pred=9.559290447214153e-06  ref=1e-05  err=4.4070955278584815e-07
#     cross_length                              pred=0.00039882282726466656  ref=0.00039999999999999996  err=1.1771727353334076e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00022
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00039999999999999996
#
# — Sample 14 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      67.22414      67.039711            0.184429           0.034014
#   claw_to_ground      55.49827      56.614994            1.116724           1.247073
#    cross_to_claw       2.50404       2.482283            0.021757           0.000473
#   cross_to_cross      67.22414      67.065521            0.158619           0.025160
#     claw_to_claw      58.39002      59.593807            1.203787           1.449104
# ground_to_ground     168.46092     166.682388            1.778532           3.163175
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=6.738579395459965e-05  ref=7e-05  err=2.614206045400345e-06
#     connection_pads.readout.ground_spacing    pred=4.456473106984049e-06  ref=4.1e-06  err=3.5647310698404937e-07
#     cross_length                              pred=0.0001371390389977023  ref=0.00014  err=2.860961002297687e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=7e-05
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00014
#
# — Sample 15 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     218.76721     217.924973            0.842237           0.709364
#   claw_to_ground     154.48543     154.241943            0.243487           0.059286
#    cross_to_claw      12.47846      12.505678            0.027218           0.000741
#   cross_to_cross     218.76721     217.842987            0.924223           0.854188
#     claw_to_claw     167.52220     167.041550            0.480650           0.231025
# ground_to_ground     444.85877     442.935852            1.922918           3.697613
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0003441968001425266  ref=0.00034999999999999994  err=5.803199857473316e-06
#     connection_pads.readout.ground_spacing    pred=4.342799456935609e-06  ref=4.1e-06  err=2.4279945693560905e-07
#     cross_length                              pred=0.0004140879900660366  ref=0.00042  err=5.9120099339634354e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00034999999999999994
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00042
#
# — Sample 16 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      40.86700      44.415936            3.548936          12.594943
#   claw_to_ground      55.00050      54.358082            0.642418           0.412701
#    cross_to_claw       2.94925       2.699791            0.249459           0.062230
#   cross_to_cross      40.86700      44.436249            3.569249          12.739537
#     claw_to_claw      58.42185      57.615669            0.806181           0.649927
# ground_to_ground     136.44316     137.798004            1.354844           1.835603
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=6.659259088337421e-05  ref=7e-05  err=3.4074091166257797e-06
#     connection_pads.readout.ground_spacing    pred=4.167214228800731e-06  ref=4.1e-06  err=6.721422880073107e-08
#     cross_length                              pred=9.970986138796434e-05  ref=9e-05  err=9.709861387964332e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=7e-05
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=9e-05
#
# — Sample 17 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      67.73716      67.696785            0.040375           0.001630
#   claw_to_ground      62.56628      62.375595            0.190685           0.036361
#    cross_to_claw       2.06963       2.104368            0.034738           0.001207
#   cross_to_cross      67.73716      67.709259            0.027901           0.000778
#     claw_to_claw      65.04248      65.026398            0.016082           0.000259
# ground_to_ground     176.41409     173.553986            2.860104           8.180197
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=7.505321264034137e-05  ref=8e-05  err=4.946787359658635e-06
#     connection_pads.readout.ground_spacing    pred=8.846374839777127e-06  ref=1e-05  err=1.153625160222874e-06
#     cross_length                              pred=0.00013789109652861953  ref=0.00014  err=2.10890347138046e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=8e-05
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00014
#
# — Sample 18 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     215.48153     215.444351            0.037179           0.001382
#   claw_to_ground     130.52289     130.812134            0.289244           0.083662
#    cross_to_claw       9.69242       9.755286            0.062866           0.003952
#   cross_to_cross     215.48153     215.455521            0.026009           0.000676
#     claw_to_claw     140.71220     140.860153            0.147953           0.021890
# ground_to_ground     416.74987     416.242126            0.507744           0.257803
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00027657882310450077  ref=0.00028  err=3.421176895499205e-06
#     connection_pads.readout.ground_spacing    pred=4.312370947445743e-06  ref=4.1e-06  err=2.1237094744574308e-07
#     cross_length                              pred=0.0004061306535732001  ref=0.00041  err=3.8693464267998846e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00028
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00041
#
# — Sample 19 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     128.46907     128.482971            0.013901           0.000193
#   claw_to_ground      92.25534      92.373756            0.118416           0.014022
#    cross_to_claw       6.12405       6.064850            0.059200           0.003505
#   cross_to_cross     128.46907     128.458557            0.010513           0.000111
#     claw_to_claw      98.81104      98.881020            0.069980           0.004897
# ground_to_ground     278.09981     275.925934            2.173876           4.725738
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00017546136223245412  ref=0.00018  err=4.53863776754589e-06
#     connection_pads.readout.ground_spacing    pred=4.374512627691729e-06  ref=4.1e-06  err=2.745126276917293e-07
#     cross_length                              pred=0.0002569631615187973  ref=0.00026  err=3.036838481202699e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00018
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00026
#
# — Sample 20 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     209.09563     209.428787            0.333157           0.110994
#   claw_to_ground     140.91684     141.353851            0.437011           0.190979
#    cross_to_claw      10.93887      11.027123            0.088253           0.007789
#   cross_to_cross     209.09563     209.476212            0.380582           0.144842
#     claw_to_claw     152.37090     152.672165            0.301265           0.090761
# ground_to_ground     420.25420     420.230682            0.023518           0.000553
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00030900226556696  ref=0.00031  err=9.977344330400228e-07
#     connection_pads.readout.ground_spacing    pred=4.326017005951144e-06  ref=4.1e-06  err=2.260170059511441e-07
#     cross_length                              pred=0.00039880513213574886  ref=0.00039999999999999996  err=1.1948678642511017e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00031
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00039999999999999996
#
# — Sample 21 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      80.37409      80.336075            0.038015           0.001445
#   claw_to_ground      75.05616      74.757576            0.298584           0.089152
#    cross_to_claw       3.05308       3.076062            0.022982           0.000528
#   cross_to_cross      80.37409      80.337540            0.036550           0.001336
#     claw_to_claw      78.57692      78.356262            0.220658           0.048690
# ground_to_ground     203.34418     201.104050            2.240130           5.018184
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010952880256809294  ref=0.00011  err=4.711974319070617e-07
#     connection_pads.readout.ground_spacing    pred=9.011945621750783e-06  ref=9.1e-06  err=8.80543782492161e-08
#     cross_length                              pred=0.00016219954704865813  ref=0.00016  err=2.1995470486581195e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00016
#
# — Sample 22 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     171.52216     171.855972            0.333812           0.111431
#   claw_to_ground     121.41730     121.563416            0.146116           0.021350
#    cross_to_claw       8.33617       8.343783            0.007613           0.000058
#   cross_to_cross     171.52216     171.812469            0.290309           0.084280
#     claw_to_claw     130.22102     130.343918            0.122898           0.015104
# ground_to_ground     356.80193     356.152679            0.649251           0.421526
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0002495539956726134  ref=0.00025  err=4.4600432738662286e-07
#     connection_pads.readout.ground_spacing    pred=5.361310286389198e-06  ref=5e-06  err=3.6131028638919775e-07
#     cross_length                              pred=0.00033125843037851155  ref=0.00033  err=1.2584303785115498e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00025
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00033
#
# — Sample 23 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     186.08458     186.822067            0.737487           0.543887
#   claw_to_ground     108.08004     108.138115            0.058075           0.003373
#    cross_to_claw       5.10324       5.259083            0.155843           0.024287
#   cross_to_cross     186.08458     186.818771            0.734191           0.539037
#     claw_to_claw     113.60879     113.749176            0.140386           0.019708
# ground_to_ground     360.09105     359.820160            0.270890           0.073381
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00020108872558921576  ref=0.00019999999999999998  err=1.088725589215773e-06
#     connection_pads.readout.ground_spacing    pred=8.842578608891927e-06  ref=9.1e-06  err=2.5742139110807256e-07
#     cross_length                              pred=0.00035183579893782735  ref=0.00034999999999999994  err=1.8357989378274065e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00019999999999999998
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00034999999999999994
#
# — Sample 24 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      89.54317      90.168610            0.625440           0.391175
#   claw_to_ground      82.33529      82.604752            0.269462           0.072610
#    cross_to_claw       4.93333       4.950644            0.017314           0.000300
#   cross_to_cross      89.54317      90.136734            0.593564           0.352318
#     claw_to_claw      87.77313      88.129890            0.356760           0.127278
# ground_to_ground     221.72004     220.642517            1.077523           1.161056
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001402566849719733  ref=0.00014  err=2.5668497197331224e-07
#     connection_pads.readout.ground_spacing    pred=5.140373104950413e-06  ref=5e-06  err=1.403731049504127e-07
#     cross_length                              pred=0.00018292914319317788  ref=0.00018  err=2.9291431931778675e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00014
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00018
#
# — Sample 25 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     205.65276     205.963257            0.310497           0.096408
#   claw_to_ground     116.69334     116.880287            0.186947           0.034949
#    cross_to_claw       8.21753       8.224067            0.006537           0.000043
#   cross_to_cross     205.65276     205.985275            0.332515           0.110566
#     claw_to_claw     125.37727     125.441803            0.064533           0.004165
# ground_to_ground     391.73856     391.178070            0.560490           0.314149
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0002391778107266873  ref=0.00023999999999999998  err=8.221892733126668e-07
#     connection_pads.readout.ground_spacing    pred=4.432079549587797e-06  ref=4.1e-06  err=3.3207954958779766e-07
#     cross_length                              pred=0.00038996164221316576  ref=0.00039  err=3.83577868342329e-08
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00023999999999999998
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00039
#
# — Sample 26 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     183.37338     183.347290            0.026090           0.000681
#   claw_to_ground     102.93749     103.317810            0.380320           0.144643
#    cross_to_claw       6.93234       6.824131            0.108209           0.011709
#   cross_to_cross     183.37338     183.323761            0.049619           0.002462
#     claw_to_claw     110.29724     110.519272            0.222032           0.049298
# ground_to_ground     352.76604     351.263763            1.502277           2.256835
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.000205012402147986  ref=0.00021  err=4.987597852014014e-06
#     connection_pads.readout.ground_spacing    pred=4.489605089474935e-06  ref=4.1e-06  err=3.896050894749354e-07
#     cross_length                              pred=0.00035461809602566063  ref=0.00036  err=5.381903974339389e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00021
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00036
#
# — Sample 27 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     136.20133     137.381424            1.180094           1.392622
#   claw_to_ground     120.43722     121.411186            0.973966           0.948610
#    cross_to_claw       9.17838       9.372260            0.193880           0.037589
#   cross_to_cross     136.20133     137.352966            1.151636           1.326266
#     claw_to_claw     130.19136     131.211685            1.020325           1.041063
# ground_to_ground     314.95950     315.697632            0.738132           0.544839
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00025242374977096915  ref=0.00025  err=2.4237497709691472e-06
#     connection_pads.readout.ground_spacing    pred=5.107291144668125e-06  ref=5e-06  err=1.0729114466812421e-07
#     cross_length                              pred=0.0002729605184867978  ref=0.00026999999999999995  err=2.9605184867978604e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00025
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00026999999999999995
#
# — Sample 28 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     143.80946     143.951767            0.142307           0.020251
#   claw_to_ground     125.37892     125.134224            0.244696           0.059876
#    cross_to_claw       7.12592       7.314452            0.188532           0.035544
#   cross_to_cross     143.80946     143.902802            0.093342           0.008713
#     claw_to_claw     133.08513     132.929703            0.155427           0.024158
# ground_to_ground     328.24034     326.989471            1.250869           1.564672
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0002498447138350457  ref=0.00025  err=1.552861649543099e-07
#     connection_pads.readout.ground_spacing    pred=8.739310942473821e-06  ref=9.1e-06  err=3.6068905752617793e-07
#     cross_length                              pred=0.00028084611403755844  ref=0.00028  err=8.461140375584609e-07
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00025
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00028
#
# — Sample 29 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     154.56183     154.626572            0.064742           0.004191
#   claw_to_ground      73.59109      73.382881            0.208209           0.043351
#    cross_to_claw       2.50326       2.632860            0.129600           0.016796
#   cross_to_cross     154.56183     154.577057            0.015227           0.000232
#     claw_to_claw      76.44597      76.426109            0.019861           0.000394
# ground_to_ground     289.12750     286.816254            2.311246           5.341860
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010456502059241757  ref=0.00011  err=5.434979407582436e-06
#     connection_pads.readout.ground_spacing    pred=8.98942926141899e-06  ref=1e-05  err=1.01057073858101e-06
#     cross_length                              pred=0.00029169212211854756  ref=0.0002999999999999999  err=8.30787788145236e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.0002999999999999999
#
# — Sample 30 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     147.85719     147.897614            0.040424           0.001634
#   claw_to_ground      69.34483      69.539635            0.194805           0.037949
#    cross_to_claw       3.53509       3.472992            0.062098           0.003856
#   cross_to_cross     147.85719     147.902603            0.045413           0.002062
#     claw_to_claw      73.22926      73.382393            0.153133           0.023450
# ground_to_ground     277.12653     275.322845            1.803685           3.253278
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00010631439363351092  ref=0.00011  err=3.6856063664890865e-06
#     connection_pads.readout.ground_spacing    pred=4.39568930232781e-06  ref=4.1e-06  err=2.9568930232781015e-07
#     cross_length                              pred=0.0002863630070351064  ref=0.00029  err=3.636992964893581e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00029
#
# — Sample 31 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     164.91926     164.945282            0.026022           0.000677
#   claw_to_ground      82.78064      82.515770            0.264870           0.070156
#    cross_to_claw       3.23513       3.323360            0.088230           0.007785
#   cross_to_cross     164.91926     164.923294            0.004034           0.000016
#     claw_to_claw      86.34713      86.228363            0.118767           0.014106
# ground_to_ground     309.83839     308.183533            1.654857           2.738553
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001301105658058077  ref=0.00013  err=1.1056580580772108e-07
#     connection_pads.readout.ground_spacing    pred=8.829701073409524e-06  ref=9.1e-06  err=2.7029892659047546e-07
#     cross_length                              pred=0.0003106710792053491  ref=0.00031  err=6.710792053490878e-07
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00013
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00031
#
# — Sample 32 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     156.19781     156.409271            0.211461           0.044716
#   claw_to_ground      92.52097      93.094925            0.573955           0.329424
#    cross_to_claw       5.93444       5.844792            0.089648           0.008037
#   cross_to_cross     156.19781     156.409210            0.211400           0.044690
#     claw_to_claw      98.86794      99.335548            0.467608           0.218658
# ground_to_ground     310.66254     309.304901            1.357639           1.843183
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00017502729315310717  ref=0.00018  err=4.972706846892845e-06
#     connection_pads.readout.ground_spacing    pred=4.476655249163741e-06  ref=4.1e-06  err=3.7665524916374154e-07
#     cross_length                              pred=0.0003051106759812683  ref=0.00031  err=4.889324018731713e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00018
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00031
#
# — Sample 33 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      56.26003      56.104561            0.155469           0.024171
#   claw_to_ground      58.64577      58.752602            0.106832           0.011413
#    cross_to_claw       2.98994       2.870023            0.119917           0.014380
#   cross_to_cross      56.26003      56.130630            0.129400           0.016744
#     claw_to_claw      62.08519      62.147377            0.062187           0.003867
# ground_to_ground     158.55983     156.004089            2.555741           6.531810
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=7.513030868722126e-05  ref=8e-05  err=4.869691312778748e-06
#     connection_pads.readout.ground_spacing    pred=4.3878440010303166e-06  ref=4.1e-06  err=2.8784400103031687e-07
#     cross_length                              pred=0.00011878469376824796  ref=0.00011999999999999999  err=1.2153062317520275e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=8e-05
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00011999999999999999
#
# — Sample 34 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     164.34477     164.608994            0.264224           0.069814
#   claw_to_ground      89.98109      89.840370            0.140720           0.019802
#    cross_to_claw       3.77364       3.873887            0.100247           0.010049
#   cross_to_cross     164.34477     164.618195            0.273425           0.074761
#     claw_to_claw      94.11389      94.096161            0.017729           0.000314
# ground_to_ground     316.44733     315.250122            1.197208           1.433307
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00015037754201330245  ref=0.00015  err=3.7754201330245855e-07
#     connection_pads.readout.ground_spacing    pred=8.859197805577423e-06  ref=9.1e-06  err=2.4080219442257585e-07
#     cross_length                              pred=0.00031105458037927747  ref=0.00031  err=1.0545803792774678e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00015
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00031
#
# — Sample 35 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     161.19793     161.418076            0.220146           0.048464
#   claw_to_ground      99.29276      99.832283            0.539523           0.291085
#    cross_to_claw       6.64752       6.550810            0.096710           0.009353
#   cross_to_cross     161.19793     161.406036            0.208106           0.043308
#     claw_to_claw     106.41913     106.783676            0.364546           0.132894
# ground_to_ground     322.87581     322.062988            0.812822           0.660679
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00019487632380332798  ref=0.00019999999999999998  err=5.123676196672005e-06
#     connection_pads.readout.ground_spacing    pred=4.492055722948862e-06  ref=4.1e-06  err=3.9205572294886253e-07
#     cross_length                              pred=0.00031515455339103937  ref=0.00031999999999999997  err=4.8454466089606005e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00019999999999999998
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00031999999999999997
#
# — Sample 36 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     157.36511     157.822372            0.457262           0.209089
#   claw_to_ground     112.04578     112.130219            0.084439           0.007130
#    cross_to_claw       5.50703       5.756038            0.249008           0.062005
#   cross_to_cross     157.36511     157.800400            0.435290           0.189477
#     claw_to_claw     118.08393     118.315681            0.231751           0.053709
# ground_to_ground     330.32287     330.063934            0.258936           0.067048
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0002124353195540607  ref=0.00021  err=2.435319554060689e-06
#     connection_pads.readout.ground_spacing    pred=8.848265679262113e-06  ref=9.1e-06  err=2.5173432073788644e-07
#     cross_length                              pred=0.0003028339706361294  ref=0.0002999999999999999  err=2.8339706361294598e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00021
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.0002999999999999999
#
# — Sample 37 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     194.21152     194.561111            0.349591           0.122214
#   claw_to_ground      79.37310      79.159706            0.213394           0.045537
#    cross_to_claw       2.92829       3.036467            0.108177           0.011702
#   cross_to_cross     194.21152     194.494781            0.283261           0.080237
#     claw_to_claw      82.58741      82.548508            0.038902           0.001513
# ground_to_ground     340.33584     339.141144            1.194696           1.427299
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00012094965495634824  ref=0.00011999999999999999  err=9.496549563482509e-07
#     connection_pads.readout.ground_spacing    pred=8.699132195033599e-06  ref=9.1e-06  err=4.008678049664006e-07
#     cross_length                              pred=0.00036078240373171866  ref=0.00036  err=7.824037317186367e-07
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00011999999999999999
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00036
#
# — Sample 38 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     142.49987     142.494888            0.004982           0.000025
#   claw_to_ground      80.30763      80.179672            0.127958           0.016373
#    cross_to_claw       3.01723       3.186669            0.169439           0.028709
#   cross_to_cross     142.49987     142.497025            0.002845           0.000008
#     claw_to_claw      83.71061      83.781921            0.071311           0.005085
# ground_to_ground     282.09379     279.562561            2.531229           6.407120
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.000123562291264534  ref=0.00013  err=6.437708735465992e-06
#     connection_pads.readout.ground_spacing    pred=8.983409315987956e-06  ref=1e-05  err=1.016590684012045e-06
#     cross_length                              pred=0.00027174674323759973  ref=0.00028  err=8.253256762400245e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00013
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00028
#
# — Sample 39 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     185.99283     185.761459            0.231371           0.053532
#   claw_to_ground      98.06706      97.762360            0.304700           0.092842
#    cross_to_claw       4.17102       4.337654            0.166634           0.027767
#   cross_to_cross     185.99283     185.744507            0.248323           0.061664
#     claw_to_claw     102.61514     102.469933            0.145207           0.021085
# ground_to_ground     350.52690     348.176086            2.350814           5.526324
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001725481852190569  ref=0.00018  err=7.451814780943107e-06
#     connection_pads.readout.ground_spacing    pred=9.265764674637467e-06  ref=1e-05  err=7.342353253625341e-07
#     cross_length                              pred=0.0003502346808090806  ref=0.00036  err=9.765319190919422e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00018
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00036
#
# — Sample 40 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     186.70783     186.478912            0.228918           0.052403
#   claw_to_ground     119.22500     119.357071            0.132071           0.017443
#    cross_to_claw       8.69031       8.578833            0.111477           0.012427
#   cross_to_cross     186.70783     186.419678            0.288152           0.083032
#     claw_to_claw     128.47678     128.357803            0.118977           0.014155
# ground_to_ground     373.15637     371.395905            1.760465           3.099239
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00025261082919314504  ref=0.00026  err=7.3891708068549405e-06
#     connection_pads.readout.ground_spacing    pred=4.50893185188761e-06  ref=4.1e-06  err=4.089318518876101e-07
#     cross_length                              pred=0.00036318667116574943  ref=0.00037  err=6.813328834250564e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00026
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00037
#
# — Sample 41 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      93.71326      95.012627            1.299367           1.688354
#   claw_to_ground      92.44203      93.428848            0.986818           0.973810
#    cross_to_claw       6.39665       6.728525            0.331875           0.110141
#   cross_to_cross      93.71326      95.074646            1.361386           1.853372
#     claw_to_claw      99.39243     100.574684            1.182254           1.397725
# ground_to_ground     236.82421     237.315033            0.490823           0.240907
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00017379688506480306  ref=0.00017  err=3.7968850648030517e-06
#     connection_pads.readout.ground_spacing    pred=4.756314410769846e-06  ref=5e-06  err=2.436855892301541e-07
#     cross_length                              pred=0.00019459253235254437  ref=0.00019  err=4.592532352544357e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00017
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00019
#
# — Sample 42 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     158.00323     158.600296            0.597066           0.356488
#   claw_to_ground      86.64982      86.606674            0.043146           0.001862
#    cross_to_claw       4.77891       4.780486            0.001576           0.000002
#   cross_to_cross     158.00323     158.586060            0.582830           0.339690
#     claw_to_claw      91.82307      91.782150            0.040920           0.001674
# ground_to_ground     305.87565     304.899658            0.975992           0.952560
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00014983443543314934  ref=0.00015  err=1.655645668506491e-07
#     connection_pads.readout.ground_spacing    pred=5.198778126214165e-06  ref=5e-06  err=1.9877812621416483e-07
#     cross_length                              pred=0.00030221190536394715  ref=0.0002999999999999999  err=2.2119053639472336e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00015
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.0002999999999999999
#
# — Sample 43 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     121.34979     120.937378            0.412412           0.170084
#   claw_to_ground      55.81940      56.127708            0.308308           0.095054
#    cross_to_claw       2.33458       2.242408            0.092172           0.008496
#   cross_to_cross     121.34979     120.982300            0.367490           0.135049
#     claw_to_claw      58.41760      58.683853            0.266253           0.070891
# ground_to_ground     232.36298     230.013885            2.349095           5.518245
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=6.567544915014878e-05  ref=7e-05  err=4.324550849851215e-06
#     connection_pads.readout.ground_spacing    pred=4.378445737529546e-06  ref=4.1e-06  err=2.784457375295463e-07
#     cross_length                              pred=0.00023505950230173767  ref=0.00023999999999999998  err=4.940497698262313e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=7e-05
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00023999999999999998
#
# — Sample 44 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     135.97879     136.228775            0.249985           0.062493
#   claw_to_ground      75.88477      76.502502            0.617732           0.381593
#    cross_to_claw       4.23694       4.174555            0.062385           0.003892
#   cross_to_cross     135.97879     136.222061            0.243271           0.059181
#     claw_to_claw      80.48310      81.091705            0.608605           0.370400
# ground_to_ground     270.32897     268.696198            1.632772           2.665946
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0001256387768080458  ref=0.00013  err=4.361223191954184e-06
#     connection_pads.readout.ground_spacing    pred=4.475520199775929e-06  ref=4.1e-06  err=3.755201997759289e-07
#     cross_length                              pred=0.0002659250458236784  ref=0.00026999999999999995  err=4.074954176321575e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00013
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00026999999999999995
#
# — Sample 45 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     101.58489     101.907753            0.322863           0.104241
#   claw_to_ground      89.39401      89.424583            0.030573           0.000935
#    cross_to_claw       4.10747       4.213253            0.105783           0.011190
#   cross_to_cross     101.58489     101.932335            0.347445           0.120718
#     claw_to_claw      94.01724      94.107681            0.090441           0.008180
# ground_to_ground     242.67125     241.295410            1.375840           1.892935
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00015018742124084383  ref=0.00015  err=1.8742124084384563e-07
#     connection_pads.readout.ground_spacing    pred=8.948498361860402e-06  ref=9.1e-06  err=1.5150163813959734e-07
#     cross_length                              pred=0.00020261763711459935  ref=0.00019999999999999998  err=2.6176371145993646e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00015
#     connection_pads.readout.ground_spacing    ref=9.1e-06
#     cross_length                              ref=0.00019999999999999998
#
# — Sample 46 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     190.85907     189.584869            1.274201           1.623587
#   claw_to_ground     132.60867     131.873444            0.735226           0.540558
#    cross_to_claw      10.25834      10.163297            0.095043           0.009033
#   cross_to_cross     190.85907     189.564575            1.294495           1.675717
#     claw_to_claw     143.42262     142.430435            0.992185           0.984431
# ground_to_ground     391.38400     387.993347            3.390653          11.496527
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00029185586026869714  ref=0.0003  err=8.144139731302831e-06
#     connection_pads.readout.ground_spacing    pred=4.387160515761934e-06  ref=4.1e-06  err=2.871605157619345e-07
#     cross_length                              pred=0.00037241546669974923  ref=0.00038  err=7.58453330025079e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.0003
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.00038
#
# — Sample 47 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     175.27419     175.305664            0.031474           0.000991
#   claw_to_ground      91.04597      90.848808            0.197162           0.038873
#    cross_to_claw       3.68023       3.850198            0.169968           0.028889
#   cross_to_cross     175.27419     175.291092            0.016902           0.000286
#     claw_to_claw      95.12638      95.083183            0.043197           0.001866
# ground_to_ground     330.98552     328.857666            2.127854           4.527763
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00015302766405511647  ref=0.00016000000000000004  err=6.9723359448835656e-06
#     connection_pads.readout.ground_spacing    pred=9.229711395164486e-06  ref=1e-05  err=7.702886048355148e-07
#     cross_length                              pred=0.00033045196323655546  ref=0.00034  err=9.548036763444567e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00016000000000000004
#     connection_pads.readout.ground_spacing    ref=1e-05
#     cross_length                              ref=0.00034
#
# — Sample 48 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     115.14761     116.003288            0.855678           0.732185
#   claw_to_ground     107.02111     107.782333            0.761223           0.579461
#    cross_to_claw       7.78498       8.063597            0.278617           0.077627
#   cross_to_cross     115.14761     116.002502            0.854892           0.730841
#     claw_to_claw     115.38621     116.279419            0.893209           0.797822
# ground_to_ground     276.51308     276.683167            0.170087           0.028929
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.0002138157287845388  ref=0.00021  err=3.815728784538797e-06
#     connection_pads.readout.ground_spacing    pred=5.0223147809447255e-06  ref=5e-06  err=2.231478094472509e-08
#     cross_length                              pred=0.0002335799508728087  ref=0.00023  err=3.579950872808688e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00021
#     connection_pads.readout.ground_spacing    ref=5e-06
#     cross_length                              ref=0.00023
#
# — Sample 49 (Unscaled) — Capacitance reconstruction
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     150.28208     150.496750            0.214670           0.046083
#   claw_to_ground      95.69848      96.215096            0.516616           0.266892
#    cross_to_claw       6.33415       6.235417            0.098733           0.009748
#   cross_to_cross     150.28208     150.480194            0.198114           0.039249
#     claw_to_claw     102.51089     102.867279            0.356389           0.127013
# ground_to_ground     306.81832     305.586700            1.231620           1.516887
#
#   Predicted Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.00018485427426639944  ref=0.00019  err=5.145725733600567e-06
#     connection_pads.readout.ground_spacing    pred=4.457354407350067e-06  ref=4.1e-06  err=3.5735440735006734e-07
#     cross_length                              pred=0.00029556488152593374  ref=0.0002999999999999999  err=4.435118474066177e-06
#
#   Reference Quantum Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.00019
#     connection_pads.readout.ground_spacing    ref=4.1e-06
#     cross_length                              ref=0.0002999999999999999
#
# Global unscaled cap reconstruction error stats:
#   min abs_error: 0.00014930175781557864
#   median abs_error: 0.2603505456542976
#   max abs_error: 5.742028286132808

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# Lets see how good we actually did

# %%
## percentage error surrogatereconstructed capacitance vs actual input capacitance
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(cap_pred_unscaled - X_test_unscaled) / (np.abs(X_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_cap_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_cap_params)]
all_pct = pct_errors_unscaled.ravel()

print(f'This is: |surrogate(predicted_qiskit_params) - actual_capacitance| / |actual_capacitance| * 100')
print(f'Samples: {n_samples}, Capacitance columns: {n_cap_params}')
# Out:
# This is: |surrogate(predicted_qiskit_params) - actual_capacitance| / |actual_capacitance| * 100
# Samples: 291, Capacitance columns: 6

# %%
## box plot showing % error distribution per capacitance output
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Surrogate Loss: % Error in Reconstructed Capacitance\n(surrogate(predicted_params) vs actual input capacitance)')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'surrogate_loss_cap_recon_pct_error_boxplot.pdf'))
plt.show()
# Out:
# /tmp/ipykernel_267794/1897351026.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,

# %%
## histogram it too
n_cols_grid = 3
n_rows_grid = math.ceil(n_cap_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_cap_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

for k in range(n_cap_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Surrogate Loss: Cap Reconstruction % Error Histograms\n(surrogate(predicted_params) vs actual input capacitance)', fontsize=13, y=1.02)
plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'surrogate_loss_cap_recon_pct_error_histograms.pdf'))
plt.show()

# %%
## look at the stats nicely
print('Capacitance Reconstruction % Error: surrogate(predicted_params) vs actual input capacitance')
print()
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_cap_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'All outputs':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")
# Out:
# Capacitance Reconstruction % Error: surrogate(predicted_params) vs actual input capacitance
#
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# cross_to_ground                 0.20       0.36       0.78       8.68
# claw_to_ground                  0.29       0.39       0.81       2.25
# cross_to_claw                   2.81       3.03       5.62      11.31
# cross_to_cross                  0.19       0.36       0.80       8.73
# claw_to_claw                    0.23       0.35       0.77       2.36
# ground_to_ground                0.60       0.62       1.10       2.84
# ----------------------------------------------------------------------
# All outputs                     0.35       0.85       2.25      11.31

# %%
## scatter plot
fig, ax = plt.subplots(figsize=(8, 6))
for j in range(n_cap_params):
    col_pct = pct_errors_unscaled[:, j]
    ax.scatter(np.full(len(col_pct), j), col_pct, s=18, alpha=0.6)
ax.set_xticks(range(n_cap_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percent Difference [%]')
ax.set_title('Percent Difference: Capacitance Matrices')
ax.set_ylim(0, None)
ax.margins(y=0)
ax.set_xlim(-0.5, n_cap_params - 0.5)
plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'surrogate_loss_cap_recon_pct_scatter.pdf'))
plt.show()

# %% [markdown]
# ## EM simulator Results

# %%
df = pd.read_csv(str(Path(RESULTS_DIR) / 'validation/ML_with_EM_sim_results_for_combined_models.csv'))
cap_names = df['param'].unique()
eps = 1e-15

## compute % errors for both comparisons
df['pct_ansys_vs_ref'] = abs(100 * (df['ansys_unscaled'] - df['ref_unscaled']) / (np.abs(df['ref_unscaled']) + eps))
df['pct_ansys_vs_pred'] = abs(100 * (df['ansys_unscaled'] - df['pred_unscaled']) / (np.abs(df['pred_unscaled']) + eps))

## pLOT 1 EM simulator vs Ref (desired cap) per capacitance column
n_caps = len(cap_names)
n_cols_grid = 3
n_rows_grid = math.ceil(n_caps / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()
for j, cap in enumerate(cap_names):
    sub = df[df['param'] == cap]
    ax = axes[j]
    ax.hist(sub['pct_ansys_vs_ref'], bins=20, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(sub['pct_ansys_vs_ref'].median(), color='red', linestyle='--',
               label=f'Median: {sub["pct_ansys_vs_ref"].median():.2f}%')
    ax.axvline(sub['pct_ansys_vs_ref'].mean(), color='orange', linestyle='--',
               label=f'Mean: {sub["pct_ansys_vs_ref"].mean():.2f}%')
    ax.set_title(cap, fontsize=10)
    ax.set_xlabel('% Difference')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)
for k in range(n_caps, len(axes)):
    fig.delaxes(axes[k])
fig.suptitle('EM simulator simulated output design of NN vs Desired Capacitance', fontsize=13, y=1.02)
plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'em_sim_vs_ref_histograms.pdf'))
plt.show()

## pLOT 2 EM simulator vs Surrogate Prediction per capacitance column
fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()
for j, cap in enumerate(cap_names):
    sub = df[df['param'] == cap]
    ax = axes[j]
    ax.hist(sub['pct_ansys_vs_pred'], bins=20, edgecolor='black', alpha=0.7, color='coral')
    ax.axvline(sub['pct_ansys_vs_pred'].median(), color='red', linestyle='--',
               label=f'Median: {sub["pct_ansys_vs_pred"].median():.2f}%')
    ax.axvline(sub['pct_ansys_vs_pred'].mean(), color='orange', linestyle='--',
               label=f'Mean: {sub["pct_ansys_vs_pred"].mean():.2f}%')
    ax.set_title(cap, fontsize=10)
    ax.set_xlabel('% Difference')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)
for k in range(n_caps, len(axes)):
    fig.delaxes(axes[k])
fig.suptitle('EM simulator vs Surrogate Prediction (pred)\n% difference per capacitance column', fontsize=13, y=1.02)
plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'em_sim_vs_pred_histograms.pdf'))
plt.show()

# %%
## pLOT 3 Scatter plots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

for j, cap in enumerate(cap_names):
    sub = df[df['param'] == cap]
    ax1.scatter(np.full(len(sub), j), sub['pct_ansys_vs_ref'].abs(), s=18, alpha=0.6)
    ax2.scatter(np.full(len(sub), j), sub['pct_ansys_vs_pred'].abs(), s=18, alpha=0.6)

for ax, title in [(ax1, 'EM simulator vs Desired (ref)'), (ax2, 'EM simulator vs Surrogate (pred)')]:
    ax.set_xticks(range(n_caps))
    ax.set_xticklabels(cap_names, rotation=45, ha='right')
    ax.set_ylabel('|% Difference|')
    ax.set_title(title)
    ax.set_ylim(0, None)
    ax.margins(y=0)
    ax.set_xlim(-0.5, n_caps - 0.5)

plt.tight_layout()
plt.savefig(str(Path(PLOTS_DIR) / 'em_sim_scatter_comparison.pdf'))
plt.show()

## stats table
print('=== EM simulator vs Desired Capacitance (ref) ===')
print(f'{"Param":<20s} {"Median %":>10s} {"Mean %":>10s} {"Max |%|":>10s}')
print('-' * 55)
for cap in cap_names:
    sub = df[df['param'] == cap]['pct_ansys_vs_ref']
    print(f'{cap:<20s} {sub.median():10.2f} {sub.mean():10.2f} {sub.abs().max():10.2f}')

print()
print('=== EM simulator vs Surrogate Prediction (pred) ===')
print(f'{"Param":<20s} {"Median %":>10s} {"Mean %":>10s} {"Max |%|":>10s}')
print('-' * 55)
for cap in cap_names:
    sub = df[df['param'] == cap]['pct_ansys_vs_pred']
    print(f'{cap:<20s} {sub.median():10.2f} {sub.mean():10.2f} {sub.abs().max():10.2f}')
